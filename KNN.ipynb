# %%
#sklearn is a machine learning library in python
from sklearn.neighbors import NearestNeighbors, KNeighborsClassifier, KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_predict
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.decomposition import PCA

# %%
train = pd.read_csv("train_KWH.csv")

# %%
train = train[train["month"] == 1]
# Out:
#        temperature  dew_point  humidity  visibility  apparent_temperature  \
# 0            51.78      43.19      0.72        8.77                 51.78
# 1            51.37      41.76      0.70        8.99                 51.37
# 2            54.00      42.19      0.64        9.55                 54.00
# 3            58.12      41.98      0.55        9.47                 58.12
# 4            61.98      43.50      0.51        9.55                 61.98
# ...            ...        ...       ...         ...                   ...
# 10891        52.59      40.74      0.64       10.00                 52.59
# 10892        48.91      40.91      0.74       10.00                 48.23
# 10893        46.37      40.59      0.80       10.00                 46.37
# 10894        44.24      39.98      0.85       10.00                 43.01
# 10895        42.78      39.68      0.89       10.00                 40.54
#
#        pressure  wind_speed  cloud_cover  wind_bearing  precip_intensity  \
# 0       1011.81        5.32         0.05           352               0.0
# 1       1012.24        4.25         0.14             4               0.0
# 2       1012.85        5.80         0.10            15               0.0
# 3       1013.19        4.96         0.22            20               0.0
# 4       1012.86        3.82         0.10            42               0.0
# ...         ...         ...          ...           ...               ...
# 10891   1022.10        3.54         0.07           310               0.0
# 10892   1022.50        3.22         0.04           315               0.0
# 10893   1023.30        2.93         0.01           312               0.0
# 10894   1023.60        3.14         0.02           299               0.0
# 10895   1024.00        3.98         0.03           286               0.0
#
#        precip_probability  hourly_kwh  hourly_solar_kWh  hourly_gal  month  \
# 0                     0.0    0.565184         -0.005276    5.115659      1
# 1                     0.0    0.520026         -0.005342    0.913526      1
# 2                     0.0    0.554724         -0.005237    0.200816      1
# 3                     0.0    0.610145         -0.005092    0.111632      1
# 4                     0.0    0.521447         -0.005224    0.405385      1
# ...                   ...         ...               ...         ...    ...
# 10891                 0.0    0.660118         -0.004294    1.952526      1
# 10892                 0.0    0.663118         -0.004529    3.068722      1
# 10893                 0.0    0.746529         -0.004353    6.084824      1
# 10894                 0.0    0.705882         -0.004294    1.169278      1
# 10895                 0.0    0.955176         -0.004412    0.894000      1
#
#        hour
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
# ...     ...
# 10891    19
# 10892    20
# 10893    21
# 10894    22
# 10895    23
#
# [2930 rows x 16 columns]

# %%
train_y = train.pop("hourly_kwh")
train_X = train[["humidity","apparent_temperature","pressure","wind_bearing","hourly_solar_kWh"]]

# %%
test = pd.read_csv("test_KWH2.csv")[["humidity","apparent_temperature","pressure","wind_bearing","hourly_solar_kWh"]]
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(train_X)
train_X_scaled = scaler.transform(train_X)

test_scaled = scaler.transform(test)

# %%
pca = PCA(n_components=4)
pca.fit(train_X_scaled)
train_X_scaled = pca.transform(train_X_scaled)
test_scaled = pca.transform(test_scaled)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.34018422, 0.30532366, 0.200009  , 0.10283641])

# %%
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(train_X_scaled, train_y)
y_pred = knn.predict(test_scaled)

pd.DataFrame(y_pred).to_csv("preds.kwh", index=False, header = False)
